# %%
# EDA for Customer Purchase Data

# 1. Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Load Data (Correctly Handling .xlsx File)
file_path = '/content/customers_data.xlsx'
df = pd.read_excel(file_path)
df.head()
# Out:
#    CustomerID            Name  Age               Purchase History
# 0           1        John Doe   28             Laptop, Smartphone
# 1           2      Jane Smith   35         Smartwatch, Headphones
# 2           3    Robert Brown   40               TV, Home Theater
# 3           4     Emily Davis   22                Tablet, Earbuds
# 4           5  Michael Wilson   50  Refrigerator, Washing Machine

# %%
# 3. Basic Data Inspection
print("\nFirst 5 Rows:")
print(df.head())

print("\nData Shape:", df.shape)
print("\nColumn Names:", df.columns.tolist())

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# First 5 Rows:
#    CustomerID            Name  Age               Purchase History
# 0           1        John Doe   28             Laptop, Smartphone
# 1           2      Jane Smith   35         Smartwatch, Headphones
# 2           3    Robert Brown   40               TV, Home Theater
# 3           4     Emily Davis   22                Tablet, Earbuds
# 4           5  Michael Wilson   50  Refrigerator, Washing Machine
#
# Data Shape: (10, 4)
#
# Column Names: ['CustomerID', 'Name', 'Age', 'Purchase History']
#
# Data Types:
# CustomerID           int64
# Name                object
# Age                  int64
# Purchase History    object
# dtype: object
#
# Missing Values:
# CustomerID          0
# Name                0
# Age                 0
# Purchase History    0
# dtype: int64
#
# Summary Statistics:
#        CustomerID        Age
# count    10.00000  10.000000
# mean      5.50000  34.800000
# std       3.02765   8.625543
# min       1.00000  22.000000
# 25%       3.25000  28.500000
# 50%       5.50000  34.000000
# 75%       7.75000  39.500000
# max      10.00000  50.000000

# %%
# 4. Univariate Analysis (Single Feature)
# Plotting Histograms for Numerical Features
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

for feature in numerical_features:
    plt.figure(figsize=(8, 4))
    df[feature].hist(bins=30)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Boxplots for Outlier Detection
for feature in numerical_features:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[feature])
    plt.title(f'Boxplot of {feature}')
    plt.show()

# %%
# Count Plots for Categorical Features
categorical_features = df.select_dtypes(include=['object']).columns

for feature in categorical_features:
    plt.figure(figsize=(8, 4))
    df[feature].value_counts().plot(kind='bar')
    plt.title(f'Count Plot of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.show()

# %%
# 5. Bivariate/Multivariate Analysis
# Pairplot for Numerical Features
sns.pairplot(df[numerical_features])
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df[numerical_features].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
 #Scatterplots between selected features (example if needed)
# sns.scatterplot(x='feature1', y='feature2', data=df)
# plt.title('Feature1 vs Feature2')
# plt.show()

# 6. Summary of Observations
print("""
Summary of Findings:
- Distribution shapes for important features.
- Presence of outliers detected through boxplots.
- Strong/weak correlations between variables.
- Possible missing data to handle.
- Imbalance in certain categories (if any).
""")
# Out:
# Summary of Findings:
# - Distribution shapes for important features.
# - Presence of outliers detected through boxplots.
# - Strong/weak correlations between variables.
# - Possible missing data to handle.
# - Imbalance in certain categories (if any).
